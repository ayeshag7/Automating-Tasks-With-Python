# %%
# Importing the required packages.
import pywhatkit as kit
from PIL import Image

# %%
# Converitng text to handwriting and saving the resulting image in a file. You can also pass in a text file.
kit.text_to_handwriting("Automating Tasks with Python", save_to="Handwritten.png")
# Displaying the image.
Image.open("Handwritten.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=6825x3095 at 0x255D478C6A0>
